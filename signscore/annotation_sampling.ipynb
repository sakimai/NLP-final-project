# %%
import json
import random
import csv

# Paths to the JSON and CSV files
json_file_path = "/home/imai.s/SLRT/CiCo/CLCL/ph_test.json"
csv_file_path = "bt_score_data.csv"

# Set the random seed for reproducibility
random.seed(42)

# Load the JSON data
with open(json_file_path, "r") as file:
    data = json.load(file)

# Create a dictionary where the key is the folder name and the value is the English transcription
folder_to_english = {
    data["original_video_dic"][key][0]: data["original_text_dic"].get(data["original_video_dic"][key][0], "No English transcription found")
    for key in data["original_video_dic"]
}

# Parse the CSV file and map folder names to German transcriptions
folder_to_german = {}
with open(csv_file_path, "r") as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        # Extract folder names from 'hyps' column
        hyp_folders = eval(row['hyps'])  # Safely evaluate the set of folder names
        german_ref = row['refs']
        for folder in hyp_folders:
            folder_to_german[folder] = german_ref

# Combine English and German transcriptions
folder_to_transcriptions = {
    folder: {
        "english": folder_to_english.get(folder, "No English transcription found"),
        "german": folder_to_german.get(folder, "No German transcription found")
    }
    for folder in folder_to_english
}

# Randomly sample 100 items
sampled_items = random.sample(folder_to_transcriptions.items(), 100)

# Convert the sampled items into a dictionary
result = {folder: transcriptions for folder, transcriptions in sampled_items}

output_path = "sampled_ph_test_with_german.json"
with open(output_path, "w", encoding="utf-8") as output_file:
    json.dump(result, output_file, indent=4, ensure_ascii=False)

# Print the result to confirm proper encoding
print(json.dumps(result, indent=4, ensure_ascii=False))
# Out:
# {
#     "03July_2011_Sunday_tagesschau-1665": {
#         "english": "In the other parts of the country, it usually gets friendly thanks to a high pressure zone that ranges from the Biscay to the Shetland Islands",
#         "german": "in den übrigen landesteilen wird es meist freundlich dank einer hochdruckzone die von der biskaya bis zu den shetlandinseln reicht ."
#     },
#     "12July_2010_Monday_tagesschau-374": {
#         "english": "Tomorrow there will be strong shower or thunderstorms in the east and southeast with a mix of sun and clouds",
#         "german": "morgen gibt es im osten und südosten bei einer mischung aus sonne und wolken zum teil kräftige schauer oder gewitter ."
#     },
#     "02December_2009_Wednesday_tagesschau-4039": {
#         "english": "And now the weather forecast for tomorrow Thursday",
#         "german": "und nun die wettervorhersage für morgen donnerstag den dritten dezember ."
#     },
#     "11November_2010_Thursday_tagesschau-3564": {
#         "english": "Sometimes heavy rain pulls eastward tonight",
#         "german": "teilweise kräftiger regen zieht heute nacht über uns ostwärts ."
#     },
#     "27August_2009_Thursday_tagesschau-3267": {
#         "english": "And now the weather forecast for tomorrow Friday the twenty -eightth August",
#         "german": "und nun die wettervorhersage für morgen freitag den achtundzwanzigsten august ."
#     },
#     "24August_2010_Tuesday_tagesschau-2196": {
#         "english": "Tonight there is also on the coasts of showers in the south, but there they gradually let go",
#         "german": "heute nacht gibt es an den küsten schauer im süden ebenfalls aber dort lassen sie allmählich nach ."
#     },
#     "08February_2010_Monday_heute-1498": {
#         "english": "And in the west we hardly have snow anymore, but there are also exceptions the low mountain range",
#         "german": "und im westen haben wir kaum noch schnee aber es gibt eben auch ausnahmen die mittelgebirge ."
#     },
#     "25November_2009_Wednesday_tagesschau-7677": {
#         "english": "On Friday changeable shower weather",
#         "german": "am freitag wechselhaftes schauerwetter ."
#     },
#     "02August_2010_Monday_heute-1243": {
#         "english": "It remains milder among the rain clouds in the east with fifteen sixteen degrees",
#         "german": "milder bleibt es unter den regenwolken im osten mit fünfzehn sechzehn grad ."
#     },
#     "29March_2010_Monday_tagesschau-8387": {
#         "english": "They bring strong shower and thunderstorms",
#         "german": "sie bringen kräftige schauer und gewitter ."
#     },
#     "16December_2009_Wednesday_tagesschau-5907": {
#         "english": "And now the weather forecast for tomorrow Thursday the seventeenth",
#         "german": "und nun die wettervorhersage für morgen donnerstag den siebzehnten dezember ."
#     },
#     "30January_2013_Wednesday_tagesschau-476": {
#         "english": "Also on Saturday it rains or snowed it spreads later in the west and north",
#         "german": "auch am samstag regnet oder schneit es verbreitet später wird es im westen und norden freundlicher ."
#     },
#     "01October_2009_Thursday_tagesschau-421": {
#         "english": "Friendly weather in the south",
#         "german": "im süden freundliches wetter ."
#     },
#     "18April_2011_Monday_tagesschau-1314": {
#         "english": "And now the weather forecast for tomorrow Tuesday, nineteenth April",
#         "german": "und nun die wettervorhersage für morgen dienstag den neunzehnten april ."
#     },
#     "14August_2011_Sunday_tagesschau-3230": {
#         "english": "This leads to violent showers and thunderstorms, some of which can be stormy",
#         "german": "dabei kommt es zu heftigen schauern und gewittern die teilweise unwetterartig sein können ."
#     },
#     "05May_2010_Wednesday_tagesschau-3360": {
#         "english": "At the weekend it gets a little warmer with shower thunderstorms and occasional sunshine in changeable weather",
#         "german": "am wochenende wird es dann etwas wärmer das ganze bei wechselhaftem wetter mit schauern gewittern und gelegentlichem sonnenschein ."
#     },
#     "17January_2011_Monday_tagesschau-7005": {
#         "english": "There is also a lot of clouds or fog in the south, but rain rarely falls there",
#         "german": "auch im süden gibt es eine menge wolken oder nebel aber regen fällt dort nur selten ."
#     },
#     "04January_2010_Monday_tagesschau-8550": {
#         "english": "In the north of moderate wind on the coasts, it sometimes blows fresh",
#         "german": "im norden mäßiger wind an den küsten weht er teilweise frisch ."
#     },
#     "17April_2010_Saturday_tagesschau-399": {
#         "english": "The air that flows to us in the coming week is much cooler",
#         "german": "die luft die in der kommenden woche zu uns strömt ist deutlich kühler ."
#     },
#     "10December_2009_Thursday_heute-7945": {
#         "english": "Sometimes a bit of snow in the northwest",
#         "german": "teilweise im nordwesten ein bisschen schneeregen ."
#     },
#     "05February_2010_Friday_tagesschau-2924": {
#         "english": "It is partly very cloudy or foggy, partly friendly with sunshine",
#         "german": "dabei ist es teils stark bewölkt oder neblig trüb teils freundlich mit sonnenschein ."
#     },
#     "11September_2009_Friday_tagesschau-8771": {
#         "english": "And now the weather forecast for tomorrow Saturday the twelfth September",
#         "german": "und nun die wettervorhersage für morgen samstag den zwölften september ."
#     },
#     "09August_2010_Monday_heute-5890": {
#         "english": "The dry heat over Russia with thirty -five to forty degrees",
#         "german": "ganz anders die trockene hitze über russland mit fünfunddreißig bis vierzig grad ."
#     },
#     "22February_2010_Monday_tagesschau-3246": {
#         "english": "In the southeast it is dry tonight, otherwise it rains strongly in the north half",
#         "german": "im südosten ist es heute nacht trocken sonst regnet es zeitweise in der nordhälfte teilweise kräftig ."
#     },
#     "26July_2010_Monday_tagesschau-6266": {
#         "english": "On Wednesday, new clouds with rain or showers from local are also spreading from the northwest",
#         "german": "am mittwoch breiten sich von nordwesten neue wolken mit regen oder schauern aus örtlich sind auch gewitter dabei ."
#     },
#     "27May_2010_Thursday_tagesschau-8382": {
#         "english": "On Sunday, the weather is sometimes inconsistent, sometimes heavy rainfalls, sometimes thunderstorms",
#         "german": "am sonntag überall unbeständiges wetter teilweise kräftige regenfälle teilweise auch gewitter ."
#     },
#     "05September_2009_Saturday_tagesschau-4085": {
#         "english": "Stormy gusts still at night on the lake",
#         "german": "in der nacht an der see noch stürmische böen ."
#     },
#     "14August_2009_Friday_tagesschau-75": {
#         "english": "Local showers or thunderstorms that can be violent",
#         "german": "örtlich schauer oder gewitter die heftig sein können ."
#     },
#     "03February_2010_Wednesday_heute-2362": {
#         "english": "I wish you a nice evening and do it well",
#         "german": "ich wünsche ihnen einen schönen abend und machen sie es gut ."
#     },
#     "06October_2012_Saturday_tagesschau-8742": {
#         "english": "There will be windy there on Tuesday there are individual showers",
#         "german": "dort wird es am dienstag windig dazu gibt es einzelne schauer ."
#     },
#     "21May_2010_Friday_tagesschau-5094": {
#         "english": "Apart from shower and thunderstorms, the wind blows weak to moderately from northwest to north",
#         "german": "abgesehen von schauer und gewitterböen weht der wind schwach bis mäßig aus nordwest bis nord ."
#     },
#     "04January_2010_Monday_tagesschau-8544": {
#         "english": "And now the weather forecast for tomorrow Tuesday, January fifth",
#         "german": "und nun die wettervorhersage für morgen dienstag den fünften januar ."
#     },
#     "03February_2010_Wednesday_heute-2355": {
#         "english": "In contrast, it will still be dry in the north",
#         "german": "im norden wird es dagegen noch trocken sein ."
#     },
#     "26August_2009_Wednesday_tagesschau-3213": {
#         "english": "And now the weather forecast for tomorrow Thursday, twenty -seven August",
#         "german": "und nun die wettervorhersage für morgen donnerstag den siebenundzwanzigsten august ."
#     },
#     "29August_2009_Saturday_tagesschau-5020": {
#         "english": "In the early hours, fog can form occasionally",
#         "german": "in den frühstunden kann sich vereinzelt nebel bilden ."
#     },
#     "11September_2009_Friday_tagesschau-8772": {
#         "english": "Relatively cool air flows to us in Germany",
#         "german": "relativ kühle luft strömt zu uns nach deutschland ."
#     },
#     "02October_2010_Saturday_tagesschau-1300": {
#         "english": "Very mild air flows to us",
#         "german": "sehr milde luft strömt zu uns ."
#     },
#     "17May_2010_Monday_heute-5576": {
#         "english": "Even relatively cool but then it looks like a few sunnier and also significantly warmer days",
#         "german": "auch noch verhältnismäßig kühl aber dann sieht es schon nach ein paar sonnigeren und auch deutlich wärmeren tagen aus ."
#     },
#     "26October_2009_Monday_tagesschau-1403": {
#         "english": "On Friday, the sun often seems to be away from the fog areas",
#         "german": "am freitag scheint abseits der nebelgebiete häufig die sonne ."
#     },
#     "23August_2010_Monday_heute-5328": {
#         "english": "Yes and so it stays on Wednesday",
#         "german": "ja und so bleibt es dann auch erstmal am mittwoch ."
#     },
#     "17July_2009_Friday_tagesschau-5104": {
#         "english": "In the cold air flowing behind it, the weather is changeable tomorrow",
#         "german": "in der dahinter einfließenden kaltluft gestaltet sich das wetter morgen wechselhaft ."
#     },
#     "24March_2011_Thursday_tagesschau-3937": {
#         "english": "During the night the clouds in the north and northeast of poets will be the first drops on the Baltic Sea",
#         "german": "in der nacht werden die wolken im norden und nordosten dichter erste tropfen können an der ostsee fallen ."
#     },
#     "09July_2010_Friday_tagesschau-591": {
#         "english": "First of all, the thunderstorm is only increased in the west from day to day it also increases to the east",
#         "german": "zunächst ist das gewitterrisiko nur im westen erhöht von tag zu tag steigt es aber auch richtung osten ."
#     },
#     "06May_2011_Friday_tagesschau-6435": {
#         "english": "Tonight twelve degrees in the Bay of Cologne and a degree in the Bavarian Forest",
#         "german": "heute nacht zwölf grad in der kölner bucht und ein grad im bayerischen wald ."
#     },
#     "13July_2009_Monday_tagesschau-7509": {
#         "english": "At the air mass border there are partially heavy and steady rainfall",
#         "german": "an der luftmassengrenze kommt es zu teilweise starken und gewittrigen regenfällen ."
#     },
#     "03July_2009_Friday_tagesschau-2014": {
#         "english": "On Sunday, especially in the east and south, shower or thunderstorms are otherwise mostly friendly",
#         "german": "am sonntag vor allem im osten und süden noch schauer oder gewitter sonst überwiegend freundlich ."
#     },
#     "06October_2011_Thursday_heute-5534": {
#         "english": "And that with deep ophelia that drives the cold air with strong showers towards Central Europe",
#         "german": "und das mit tief ophelia das die kaltluft mit kräftigen schauern richtung mitteleuropa treibt ."
#     },
#     "06September_2010_Monday_tagesschau-1153": {
#         "english": "on Thursday still unsteady but from Friday it will be slowly friendlier from the west",
#         "german": "am donnerstag noch unbeständig aber ab freitag wird es von westen langsam freundlicher ."
#     },
#     "04December_2011_Sunday_tagesschau-7791": {
#         "english": "Very windy weather on Tuesday rain snow and porridge showers",
#         "german": "sehr windiges wetter am dienstag regen schnee und graupelschauer ."
#     },
#     "01April_2010_Thursday_tagesschau-4330": {
#         "english": "It is still the friendliest in the northeast and in parts of Bavaria",
#         "german": "am freundlichsten ist es noch im nordosten sowie in teilen bayerns ."
#     },
#     "08October_2009_Thursday_tagesschau-5352": {
#         "english": "On the Baltic Sea tonight stormy gusts from west",
#         "german": "an der ostsee heute nacht stürmische böen aus west ."
#     },
#     "22July_2009_Wednesday_tagesschau-2873": {
#         "english": "At night, especially in the northwestern half of the northwest, it must be expected with showers and thunderstorms that can be violent",
#         "german": "in der nacht muss vor allem in der nordwesthälfte mit schauern und gewittern gerechnet werden die heftig ausfallen können ."
#     },
#     "31March_2010_Wednesday_tagesschau-999": {
#         "english": "And now the weather forecast for tomorrow Thursday, April 1st",
#         "german": "und nun die wettervorhersage für morgen donnerstag den ersten april ."
#     },
#     "14December_2010_Tuesday_heute-650": {
#         "english": "There even with slight plus degrees but otherwise it remains frosty",
#         "german": "dort auch bei leichten plusgraden aber sonst bleibt es frostig ."
#     },
#     "15March_2011_Tuesday_tagesschau-3326": {
#         "english": "But during the night it becomes increasingly cloudy",
#         "german": "aber im laufe der nacht wird es zunehmend wolkiger ."
#     },
#     "24October_2009_Saturday_tagesschau-4286": {
#         "english": "The wind from south to west blows weak to moderate",
#         "german": "der wind aus süd bis west weht schwach bis mäßig ."
#     },
#     "06November_2010_Saturday_tagesschau-1162": {
#         "english": "weak to moderate on the mountains in gusts even strong wind in the north half from east to northeast otherwise from different directions",
#         "german": "schwacher bis mäßiger auf den bergen in böen auch starker wind in der nordhälfte aus ost bis nordost sonst aus unterschiedlichen richtungen ."
#     },
#     "11December_2010_Saturday_tagesschau-8661": {
#         "english": "The snow border drops to six hundred to three hundred meters",
#         "german": "die schneefallgrenze sinkt auf sechshundert bis dreihundert meter ."
#     },
#     "08February_2010_Monday_heute-1497": {
#         "english": "It usually remains cloudy as in this picture here",
#         "german": "es bleibt meist trüb wie auf diesem bild hier ."
#     },
#     "06October_2012_Saturday_tagesschau-8743": {
#         "english": "In the south and southwest in areas otherwise risen quite friendly",
#         "german": "im süden und südwesten gebietsweise regen sonst recht freundlich ."
#     },
#     "13August_2009_Thursday_tagesschau-8492": {
#         "english": "The new week starts changeable and a little cooler",
#         "german": "die neue woche beginnt noch wechselhaft und etwas kühler ."
#     },
#     "24January_2013_Thursday_tagesschau-6322": {
#         "english": "Cross on Sunday and then an Atlantic deep run -down it becomes milder",
#         "german": "am sonntag überquert und dann ein atlantischer tiefausläufer dabei wird es milder ."
#     },
#     "08October_2009_Thursday_tagesschau-5358": {
#         "english": "In the east, however, friendly sections",
#         "german": "im osten aber erst noch freundliche abschnitte ."
#     },
#     "14July_2009_Tuesday_tagesschau-2430": {
#         "english": "Tonight warm thirteen to eighteen degrees",
#         "german": "heute nacht schwül warme dreizehn bis achtzehn grad ."
#     },
#     "21November_2011_Monday_heute-5437": {
#         "english": "Have a nice evening",
#         "german": "ihnen noch einen schönen abend ."
#     },
#     "08September_2010_Wednesday_tagesschau-5246": {
#         "english": "On Saturday it is still raining a little near the coast",
#         "german": "am samstag regnet es noch etwas in küstennähe sonst meist freundlich und trocken ."
#     },
#     "20April_2011_Wednesday_tagesschau-3086": {
#         "english": "A lot of sunshine later form here and there a few spring clouds form here and there again",
#         "german": "auch am tag wieder viel sonnenschein später bilden sich hier und da ein paar quellwolken ."
#     },
#     "08April_2010_Thursday_tagesschau-3957": {
#         "english": "Tomorrow the temperatures of nine degrees on the Baltic Sea to seventeen degrees in the Breisgau",
#         "german": "morgen reichen die temperaturen von neun grad an der ostsee bis siebzehn grad im breisgau ."
#     },
#     "31March_2010_Wednesday_tagesschau-1008": {
#         "english": "On Friday, the sun is clouds and only individual shower in places the sun shows itself for a long time",
#         "german": "am freitag mal sonne mal wolken und nur einzelne schauer stellenweise zeigt sich die sonne auch für längere zeit ."
#     },
#     "22September_2010_Wednesday_heute-2624": {
#         "english": "On Friday, however, it is slowly going down in the east thunderstorm",
#         "german": "am freitag geht es aber langsam abwärts im osten gewitterschauer ."
#     },
#     "28May_2010_Friday_tagesschau-7501": {
#         "english": "tonight eleven degrees in Lower Bavaria and up to one degree in the northern low mountain ranges",
#         "german": "heute nacht elf grad in niederbayern und bis ein grad in den nördlichen mittelgebirgen ."
#     },
#     "11September_2009_Friday_tagesschau-8781": {
#         "english": "The wind blows weakly to moderately on the North Sea and in the mountain country also a fresh wind",
#         "german": "der wind weht schwach bis mäßig an der nordsee und im bergland auch frischer wind ."
#     },
#     "14July_2009_Tuesday_tagesschau-2433": {
#         "english": "Especially in the southern mountain country, individual heat wives",
#         "german": "besonders im südlichen bergland einzelne wärmegewitter ."
#     },
#     "20June_2011_Monday_heute-6511": {
#         "english": "And so good evening",
#         "german": "und damit schönen guten abend ."
#     },
#     "06October_2011_Thursday_heute-5535": {
#         "english": "In the Alps it will even snow",
#         "german": "in den alpen wird es dann sogar schneien ."
#     },
#     "24April_2010_Saturday_tagesschau-3971": {
#         "english": "There is possible frost there and in unfavorable trough locations",
#         "german": "dort sowie in ungünstigen muldenlagen ist bodenfrost möglich ."
#     },
#     "14August_2011_Sunday_tagesschau-3232": {
#         "english": "In the east and south, heavy rain and hail must be expected at the beginning of the night",
#         "german": "im osten und süden muss zu beginn der nacht örtlich mit starkregen und hagel gerechnet werden ."
#     },
#     "04October_2010_Monday_tagesschau-4723": {
#         "english": "In the Erzgebirge tomorrow thirteen otherwise fifteen to twenty -two degrees",
#         "german": "im erzgebirge morgen dreizehn sonst fünfzehn bis zweiundzwanzig grad ."
#     },
#     "19April_2010_Monday_heute-782": {
#         "english": "Now I wish you a nice evening",
#         "german": "jetzt wünsche ich ihnen noch einen schönen abend ."
#     },
#     "05May_2010_Wednesday_tagesschau-3348": {
#         "english": "The strong Mediterranean deep extends its influence to the north and tomorrow ensures a cloudy sky in almost all of Germany",
#         "german": "das kräftige mittelmeertief dehnt seinen einfluss weiter nach norden aus und sorgt morgen in fast ganz deutschland für einen wolkenverhangenen himmel ."
#     },
#     "24January_2010_Sunday_tagesschau-8703": {
#         "english": "And now the weather forecast for tomorrow Monday, twenty -five January",
#         "german": "und nun die wettervorhersage für morgen montag den fünfundzwanzigsten januar ."
#     },
#     "04April_2010_Sunday_tagesschau-4574": {
#         "english": "On Tuesday it is mostly friendly in the northeast denser clouds with some rain",
#         "german": "am dienstag ist es meist freundlich im nordosten halten sich dichtere wolken mit etwas regen ."
#     },
#     "29August_2011_Monday_tagesschau-5710": {
#         "english": "Tonight there are dense clouds in the north, especially north of a line of Emsland Uckermark, it is sking",
#         "german": "heute nacht gibt es im norden dichte wolken besonders nördlich einer linie emsland uckermark schauert es ."
#     },
#     "08April_2010_Thursday_tagesschau-3961": {
#         "english": "The new week is also growing and quite cool",
#         "german": "auch die neue woche beginnt durchwachsen und recht kühl ."
#     },
#     "28July_2010_Wednesday_tagesschau-871": {
#         "english": "on Saturday mostly friendly mostly dry and warmer",
#         "german": "am samstag überwiegend freundlich meist trocken und wärmer ."
#     },
#     "16November_2009_Monday_tagesschau-3106": {
#         "english": "It gets friendlier every day from the south",
#         "german": "von süden wird es tag für tag freundlicher ."
#     },
#     "28October_2009_Wednesday_tagesschau-4544": {
#         "english": "Tomorrow temperatures of eight degrees in the northeast to seventeen in the southwest",
#         "german": "morgen temperaturen von acht grad im nordosten bis siebzehn im südwesten ."
#     },
#     "21April_2010_Wednesday_heute-3108": {
#         "english": "Good evening dear spectators",
#         "german": "guten abend liebe zuschauer ."
#     },
#     "13December_2010_Monday_tagesschau-6944": {
#         "english": "On Friday the weather calms down again",
#         "german": "am freitag beruhigt sich das wetter wieder ."
#     },
#     "24November_2009_Tuesday_tagesschau-5689": {
#         "english": "On the day ten degrees in the middle in higher locations, sixteen degrees in the south",
#         "german": "am tag zehn grad in der mitte in höheren lagen sechzehn grad im süden ."
#     },
#     "06May_2011_Friday_tagesschau-6434": {
#         "english": "The wind blows weak to moderately on the sea too",
#         "german": "der wind weht schwach bis mäßig am meer auch frisch ."
#     },
#     "30October_2009_Friday_tagesschau-2273": {
#         "english": "In the eastern half, the sun often seems to be away from the fog areas",
#         "german": "in der osthälfte scheint abseits der nebelgebiete häufig die sonne ."
#     },
#     "24March_2011_Thursday_tagesschau-3938": {
#         "english": "otherwise usually only loose clouds",
#         "german": "sonst meist nur lockere wolken ."
#     },
#     "11September_2009_Friday_tagesschau-8773": {
#         "english": "Initially, deep exporters only reach us in a weakened form",
#         "german": "tiefausläufer erreichen uns zunächst nur in abgeschwächter form ."
#     },
#     "28January_2013_Monday_tagesschau-3624": {
#         "english": "The wind already lives on storm gusts in the north at night, there are individual stormy gusts on the mountains",
#         "german": "der wind lebt bereits in der nacht auf im norden sturmböen sonst einzelne stürmische böen auf den bergen können orkanböen auftreten ."
#     },
#     "05June_2010_Saturday_tagesschau-3932": {
#         "english": "On Tuesday, especially towards the east, longer friendly sections next to it, but also showers and thunderstorms",
#         "german": "am dienstag vor allem richtung osten längere freundliche abschnitte daneben aber auch schauer und gewitter ."
#     },
#     "09June_2010_Wednesday_tagesschau-5961": {
#         "english": "The German Weather Service has published corresponding severe weather warnings",
#         "german": "der deutsche wetterdienst hat entsprechende unwetterwarnungen herausgegeben ."
#     },
#     "24November_2009_Tuesday_tagesschau-5692": {
#         "english": "Friendly sections in the south and east",
#         "german": "im süden und osten freundliche abschnitte ."
#     },
#     "14September_2010_Tuesday_heute-8239": {
#         "english": "And there is a new low that will reach us tomorrow evening then on the North Sea partly with heavy gusts of wind",
#         "german": "und es kommt ein neues tief das uns morgen abend dann erreichen wird an der nordsee zum teil mit schweren sturmböen ."
#     },
#     "09June_2010_Wednesday_heute-8260": {
#         "english": "Sometimes not under twenty degrees in some cities",
#         "german": "die kommende nacht teilweise nicht unter zwanzig grad in einigen städten ."
#     }
# }
