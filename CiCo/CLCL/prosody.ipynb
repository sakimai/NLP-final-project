# %%
import numpy as np

similarity_results = np.load("new_experiment/ph_results.npy", allow_pickle=True).item()
similarity_results
# Out:
# {'text_ids': array({'25October_2010_Monday_tagesschau-17': 'Rain and snow let go of the Alps in the night in the north and northeast falls here and there. Otherwise this is clear', '25October_2010_Monday_tagesschau-24': 'On Thursday in the northern half in the southern half of the sun, clouds of clouds similar to the weather on Friday', '15December_2010_Wednesday_tagesschau-37': 'A strong deep pulls up from the northern sea and from the morning hours there is violent snowfall sometimes also freezing rain', '10March_2011_Thursday_heute-58': 'Sunny, a wonderful day with temperatures up to seventeen degrees here in the west is also sunny.', '14August_2009_Friday_tagesschau-62': 'Germany will be under the influence of high pressure tomorrow that largely sells the clouds', '14August_2009_Friday_tagesschau-73': 'On Sunday in the northwest a mixture of sun and clouds with some sometimes thundering showers', '14August_2009_Friday_tagesschau-75': 'Local showers or thunderstorms that can be vi
# ...
